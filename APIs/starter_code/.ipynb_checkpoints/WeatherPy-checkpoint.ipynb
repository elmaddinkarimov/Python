# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import random 
import numpy as np
import requests
import json 
import datetime
import time
from api_keys import api_key
from citipy import citipy
from pprint import pprint

output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 611

# %%
#Randomly generate latitude and longitude numbers. lookup nearest city using citipy

randCity = []
randCountry = []
loopcnt = 0

#Loop through until at least 500 unique (non-repeat) city names are found

while len(randCity) < 600 :
    
    loopcnt +=1
    
    # Randomly generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    
    if lat_pos == 1:
        lat = lat * -1
    
    # Randomly generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    
    if lng_pos == 1:
        lng = lng * -1
         
    
    # Call citipy file to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add it to the city and country lists
    foundCity = False
    
    for j in range(len(randCity)):
        if city.city_name == randCity[j]:
            foundCity = True
            
    if foundCity==False  :   
        randCity.append(city.city_name)
        randCountry.append(city.country_code)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=b92b1e72d600408724344690fb8e3399&units=imperial&q=

# %%
# Loop through the list of cities and perform request for data on each
search_data = []
cityList = []
countryList = []

i = 0
j = 1
counter = 1
print("Beginning Data Retrieval  ")
print("-------------------------------")

for city in randCity:
    print(f"Processing record {i} of Set {j} | {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    
    if response.get("id"):      
        search_data.append(response)
        cityList.append(city)
        countryList.append(randCountry[i-1])
    else:
        print(f"City not found. Skipping...")
    i=i+1
    counter=counter+1
    if i==50:
        j=j+1
        i=0
          
print("-------------------------------")
print("Data Retrieval Complete ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 0 of Set 1 | mataura
# Processing record 1 of Set 1 | faya
# Processing record 2 of Set 1 | slantsy
# Processing record 3 of Set 1 | cape town
# Processing record 4 of Set 1 | sonipat
# Processing record 5 of Set 1 | gore
# Processing record 6 of Set 1 | port lincoln
# Processing record 7 of Set 1 | nikolskoye
# Processing record 8 of Set 1 | new norfolk
# Processing record 9 of Set 1 | khatanga
# Processing record 10 of Set 1 | vagay
# Processing record 11 of Set 1 | galveston
# Processing record 12 of Set 1 | tasiilaq
# Processing record 13 of Set 1 | kautokeino
# Processing record 14 of Set 1 | longyearbyen
# Processing record 15 of Set 1 | deer lake
# Processing record 16 of Set 1 | poum
# Processing record 17 of Set 1 | aksarayskiy
# Processing record 18 of Set 1 | vaini
# Processing record 19 of Set 1 | ilulissat
# Processing record 20 of Set 1 | isla vista
# Processing record 21 of Set 1 | sioux lookout
# Processing record 22 of Set 1 | santiago
# Processing record 23 of Set 1 | meulaboh
# Processing record 24 of Set 1 | pevek
# Processing record 25 of Set 1 | shenjiamen
# Processing record 26 of Set 1 | asadabad
# Processing record 27 of Set 1 | narsaq
# Processing record 28 of Set 1 | port alfred
# Processing record 29 of Set 1 | terme
# Processing record 30 of Set 1 | camacha
# Processing record 31 of Set 1 | basco
# Processing record 32 of Set 1 | issoudun
# Processing record 33 of Set 1 | minab
# Processing record 34 of Set 1 | rikitea
# Processing record 35 of Set 1 | bilma
# Processing record 36 of Set 1 | leningradskiy
# Processing record 37 of Set 1 | albany
# Processing record 38 of Set 1 | salym
# Processing record 39 of Set 1 | ayan
# Processing record 40 of Set 1 | namtsy
# Processing record 41 of Set 1 | saint-philippe
# Processing record 42 of Set 1 | hilo
# Processing record 43 of Set 1 | qaanaaq
# Processing record 44 of Set 1 | sangar
# Processing record 45 of Set 1 | palafrugell
# Processing record 46 of Set 1 | tuktoyaktuk
# Processing record 47 of Set 1 | atuona
# Processing record 48 of Set 1 | chokurdakh
# Processing record 49 of Set 1 | rungata
# City not found. Skipping...
# Processing record 0 of Set 2 | victoria
# Processing record 1 of Set 2 | bilibino
# Processing record 2 of Set 2 | inhambane
# Processing record 3 of Set 2 | byron bay
# Processing record 4 of Set 2 | denpasar
# Processing record 5 of Set 2 | richards bay
# Processing record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing record 7 of Set 2 | vao
# Processing record 8 of Set 2 | hermanus
# Processing record 9 of Set 2 | grand centre
# City not found. Skipping...
# Processing record 10 of Set 2 | xinyu
# Processing record 11 of Set 2 | constantine
# Processing record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing record 13 of Set 2 | severo-kurilsk
# Processing record 14 of Set 2 | bluff
# Processing record 15 of Set 2 | harrismith
# Processing record 16 of Set 2 | gangotri
# City not found. Skipping...
# Processing record 17 of Set 2 | thompson
# Processing record 18 of Set 2 | carnarvon
# Processing record 19 of Set 2 | vaitupu
# City not found. Skipping...
# Processing record 20 of Set 2 | namibe
# Processing record 21 of Set 2 | shakhtinsk
# Processing record 22 of Set 2 | upernavik
# Processing record 23 of Set 2 | butaritari
# Processing record 24 of Set 2 | pontianak
# Processing record 25 of Set 2 | hithadhoo
# Processing record 26 of Set 2 | sarakhs
# Processing record 27 of Set 2 | ust-ilimsk
# Processing record 28 of Set 2 | severo-yeniseyskiy
# Processing record 29 of Set 2 | jamestown
# Processing record 30 of Set 2 | ushuaia
# Processing record 31 of Set 2 | hobart
# Processing record 32 of Set 2 | batemans bay
# Processing record 33 of Set 2 | los llanos de aridane
# Processing record 34 of Set 2 | juba
# Processing record 35 of Set 2 | severnyy
# City not found. Skipping...
# Processing record 36 of Set 2 | okhotsk
# Processing record 37 of Set 2 | kaitangata
# Processing record 38 of Set 2 | lorengau
# Processing record 39 of Set 2 | baykit
# Processing record 40 of Set 2 | korla
# City not found. Skipping...
# Processing record 41 of Set 2 | ixtapa
# Processing record 42 of Set 2 | isangel
# Processing record 43 of Set 2 | hailar
# Processing record 44 of Set 2 | arraial do cabo
# Processing record 45 of Set 2 | talnakh
# Processing record 46 of Set 2 | hambantota
# Processing record 47 of Set 2 | dera baba nanak
# City not found. Skipping...
# Processing record 48 of Set 2 | bunia
# Processing record 49 of Set 2 | barrow
# Processing record 0 of Set 3 | kavaratti
# Processing record 1 of Set 3 | mar del plata
# Processing record 2 of Set 3 | sitka
# Processing record 3 of Set 3 | malwan
# City not found. Skipping...
# Processing record 4 of Set 3 | clyde river
# Processing record 5 of Set 3 | aflu
# City not found. Skipping...
# Processing record 6 of Set 3 | naliya
# Processing record 7 of Set 3 | esfahan
# Processing record 8 of Set 3 | yellowknife
# Processing record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 10 of Set 3 | tieli
# Processing record 11 of Set 3 | la trinitaria
# Processing record 12 of Set 3 | miri
# Processing record 13 of Set 3 | whyalla
# Processing record 14 of Set 3 | aleksandrovskiy zavod
# Processing record 15 of Set 3 | port blair
# Processing record 16 of Set 3 | henties bay
# Processing record 17 of Set 3 | atasu
# Processing record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing record 19 of Set 3 | port elizabeth
# Processing record 20 of Set 3 | along
# Processing record 21 of Set 3 | pionerskiy
# Processing record 22 of Set 3 | mammaste
# Processing record 23 of Set 3 | north battleford
# Processing record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing record 25 of Set 3 | katsuura
# Processing record 26 of Set 3 | ulaanbaatar
# Processing record 27 of Set 3 | souillac
# Processing record 28 of Set 3 | vardo
# Processing record 29 of Set 3 | snezhnogorsk
# Processing record 30 of Set 3 | tiksi
# Processing record 31 of Set 3 | torbay
# Processing record 32 of Set 3 | puerto ayora
# Processing record 33 of Set 3 | dikson
# Processing record 34 of Set 3 | iberia
# Processing record 35 of Set 3 | vilhena
# Processing record 36 of Set 3 | saldanha
# Processing record 37 of Set 3 | rosetta
# Processing record 38 of Set 3 | anadyr
# Processing record 39 of Set 3 | utiroa
# City not found. Skipping...
# Processing record 40 of Set 3 | taoudenni
# Processing record 41 of Set 3 | namatanai
# Processing record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing record 43 of Set 3 | tabuk
# Processing record 44 of Set 3 | thinadhoo
# Processing record 45 of Set 3 | alice springs
# Processing record 46 of Set 3 | busselton
# Processing record 47 of Set 3 | diu
# Processing record 48 of Set 3 | orgun
# City not found. Skipping...
# Processing record 49 of Set 3 | goderich
# Processing record 0 of Set 4 | kapaa
# Processing record 1 of Set 4 | kokopo
# Processing record 2 of Set 4 | kuandian
# Processing record 3 of Set 4 | tarudant
# City not found. Skipping...
# Processing record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing record 5 of Set 4 | mocambique
# City not found. Skipping...
# Processing record 6 of Set 4 | novochernorechenskiy
# Processing record 7 of Set 4 | louis trichardt
# Processing record 8 of Set 4 | otaru
# Processing record 9 of Set 4 | dno
# Processing record 10 of Set 4 | axim
# Processing record 11 of Set 4 | borujan
# City not found. Skipping...
# Processing record 12 of Set 4 | zhigansk
# Processing record 13 of Set 4 | fevralsk
# City not found. Skipping...
# Processing record 14 of Set 4 | alcudia
# Processing record 15 of Set 4 | bartica
# Processing record 16 of Set 4 | bolobo
# Processing record 17 of Set 4 | dingle
# Processing record 18 of Set 4 | houma
# Processing record 19 of Set 4 | airai
# Processing record 20 of Set 4 | muzhi
# Processing record 21 of Set 4 | saint anthony
# Processing record 22 of Set 4 | pemba
# Processing record 23 of Set 4 | zelenoborskiy
# Processing record 24 of Set 4 | avarua
# Processing record 25 of Set 4 | soyo
# Processing record 26 of Set 4 | pisco
# Processing record 27 of Set 4 | vestmannaeyjar
# Processing record 28 of Set 4 | koslan
# Processing record 29 of Set 4 | hobyo
# Processing record 30 of Set 4 | nizhneudinsk
# Processing record 31 of Set 4 | alugan
# Processing record 32 of Set 4 | jumla
# Processing record 33 of Set 4 | changli
# Processing record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing record 35 of Set 4 | bethel
# Processing record 36 of Set 4 | asau
# City not found. Skipping...
# Processing record 37 of Set 4 | punta arenas
# Processing record 38 of Set 4 | calgary
# Processing record 39 of Set 4 | kruisfontein
# Processing record 40 of Set 4 | umea
# Processing record 41 of Set 4 | saskylakh
# Processing record 42 of Set 4 | ituni
# City not found. Skipping...
# Processing record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing record 44 of Set 4 | mokhsogollokh
# Processing record 45 of Set 4 | banda aceh
# Processing record 46 of Set 4 | sovetskaya
# Processing record 47 of Set 4 | ostrovnoy
# Processing record 48 of Set 4 | viligili
# City not found. Skipping...
# Processing record 49 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing record 0 of Set 5 | yar-sale
# Processing record 1 of Set 5 | arlit
# Processing record 2 of Set 5 | kunya
# Processing record 3 of Set 5 | odweyne
# City not found. Skipping...
# Processing record 4 of Set 5 | hirara
# Processing record 5 of Set 5 | suntar
# Processing record 6 of Set 5 | hasaki
# Processing record 7 of Set 5 | norman wells
# Processing record 8 of Set 5 | honiara
# Processing record 9 of Set 5 | olafsvik
# City not found. Skipping...
# Processing record 10 of Set 5 | san patricio
# Processing record 11 of Set 5 | lompoc
# Processing record 12 of Set 5 | cabedelo
# Processing record 13 of Set 5 | seydi
# Processing record 14 of Set 5 | cherskiy
# Processing record 15 of Set 5 | daxian
# City not found. Skipping...
# Processing record 16 of Set 5 | juneau
# Processing record 17 of Set 5 | ancud
# Processing record 18 of Set 5 | matay
# Processing record 19 of Set 5 | pangnirtung
# Processing record 20 of Set 5 | phan rang
# City not found. Skipping...
# Processing record 21 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing record 22 of Set 5 | lumphat
# Processing record 23 of Set 5 | east london
# Processing record 24 of Set 5 | codrington
# Processing record 25 of Set 5 | mezen
# Processing record 26 of Set 5 | kirakira
# Processing record 27 of Set 5 | zonguldak
# Processing record 28 of Set 5 | tobolsk
# Processing record 29 of Set 5 | chagda
# City not found. Skipping...
# Processing record 30 of Set 5 | zhanakorgan
# Processing record 31 of Set 5 | sanming
# Processing record 32 of Set 5 | tagusao
# Processing record 33 of Set 5 | san lawrenz
# Processing record 34 of Set 5 | kadykchan
# City not found. Skipping...
# Processing record 35 of Set 5 | hanyang
# Processing record 36 of Set 5 | paamiut
# Processing record 37 of Set 5 | charters towers
# Processing record 38 of Set 5 | jishou
# Processing record 39 of Set 5 | kahului
# Processing record 40 of Set 5 | karaidel
# Processing record 41 of Set 5 | galle
# Processing record 42 of Set 5 | labytnangi
# Processing record 43 of Set 5 | bjornevatn
# Processing record 44 of Set 5 | hamilton
# Processing record 45 of Set 5 | georgetown
# Processing record 46 of Set 5 | salalah
# Processing record 47 of Set 5 | bonavista
# Processing record 48 of Set 5 | westport
# Processing record 49 of Set 5 | rovaniemi
# Processing record 0 of Set 6 | boralday
# Processing record 1 of Set 6 | zabinka
# City not found. Skipping...
# Processing record 2 of Set 6 | kodiak
# Processing record 3 of Set 6 | ossora
# Processing record 4 of Set 6 | abu samrah
# Processing record 5 of Set 6 | poronaysk
# Processing record 6 of Set 6 | pasni
# Processing record 7 of Set 6 | caravelas
# Processing record 8 of Set 6 | bandarbeyla
# Processing record 9 of Set 6 | mahebourg
# Processing record 10 of Set 6 | kribi
# Processing record 11 of Set 6 | batsfjord
# Processing record 12 of Set 6 | jacqueville
# Processing record 13 of Set 6 | krasnoselkup
# City not found. Skipping...
# Processing record 14 of Set 6 | ilovlya
# Processing record 15 of Set 6 | doka
# Processing record 16 of Set 6 | numan
# Processing record 17 of Set 6 | vaxjo
# City not found. Skipping...
# Processing record 18 of Set 6 | nanortalik
# Processing record 19 of Set 6 | sherpur
# Processing record 20 of Set 6 | kalmunai
# Processing record 21 of Set 6 | khandyga
# Processing record 22 of Set 6 | monrovia
# Processing record 23 of Set 6 | saint george
# Processing record 24 of Set 6 | kloulklubed
# Processing record 25 of Set 6 | pangody
# Processing record 26 of Set 6 | sturgeon bay
# Processing record 27 of Set 6 | husavik
# Processing record 28 of Set 6 | zyryanka
# Processing record 29 of Set 6 | marzuq
# Processing record 30 of Set 6 | kavieng
# Processing record 31 of Set 6 | enshi
# Processing record 32 of Set 6 | cabo san lucas
# Processing record 33 of Set 6 | esfarayen
# Processing record 34 of Set 6 | platonovka
# City not found. Skipping...
# Processing record 35 of Set 6 | pudozh
# Processing record 36 of Set 6 | zaraza
# Processing record 37 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing record 38 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing record 39 of Set 6 | dhola
# Processing record 40 of Set 6 | lasa
# Processing record 41 of Set 6 | tunceli
# Processing record 42 of Set 6 | berlevag
# Processing record 43 of Set 6 | awallan
# Processing record 44 of Set 6 | diamantina
# Processing record 45 of Set 6 | ippy
# Processing record 46 of Set 6 | kenora
# Processing record 47 of Set 6 | togur
# Processing record 48 of Set 6 | sao filipe
# Processing record 49 of Set 6 | sisimiut
# Processing record 0 of Set 7 | todos santos
# Processing record 1 of Set 7 | ponnampet
# Processing record 2 of Set 7 | yian
# City not found. Skipping...
# Processing record 3 of Set 7 | batouri
# Processing record 4 of Set 7 | bubaque
# Processing record 5 of Set 7 | castelldefels
# Processing record 6 of Set 7 | longkou
# Processing record 7 of Set 7 | panuco
# Processing record 8 of Set 7 | high level
# Processing record 9 of Set 7 | changchun
# Processing record 10 of Set 7 | turia
# Processing record 11 of Set 7 | uva
# Processing record 12 of Set 7 | plettenberg bay
# Processing record 13 of Set 7 | bredasdorp
# Processing record 14 of Set 7 | kotma
# Processing record 15 of Set 7 | cumaribo
# City not found. Skipping...
# Processing record 16 of Set 7 | kununurra
# Processing record 17 of Set 7 | gurgan
# City not found. Skipping...
# Processing record 18 of Set 7 | la asuncion
# Processing record 19 of Set 7 | rumphi
# Processing record 20 of Set 7 | constitucion
# Processing record 21 of Set 7 | logstor
# Processing record 22 of Set 7 | provideniya
# Processing record 23 of Set 7 | kuche
# City not found. Skipping...
# Processing record 24 of Set 7 | beringovskiy
# Processing record 25 of Set 7 | sayat
# Processing record 26 of Set 7 | mirandola
# Processing record 27 of Set 7 | paraiso
# Processing record 28 of Set 7 | weiser
# Processing record 29 of Set 7 | mount isa
# Processing record 30 of Set 7 | mingaora
# Processing record 31 of Set 7 | daltenganj
# Processing record 32 of Set 7 | nyurba
# Processing record 33 of Set 7 | ahipara
# Processing record 34 of Set 7 | batticaloa
# Processing record 35 of Set 7 | grindavik
# Processing record 36 of Set 7 | birin
# Processing record 37 of Set 7 | labuhan
# Processing record 38 of Set 7 | tsihombe
# City not found. Skipping...
# Processing record 39 of Set 7 | nakhon ratchasima
# Processing record 40 of Set 7 | port hedland
# Processing record 41 of Set 7 | voyvozh
# Processing record 42 of Set 7 | shiyan
# Processing record 43 of Set 7 | buraydah
# Processing record 44 of Set 7 | nurota
# Processing record 45 of Set 7 | harper
# Processing record 46 of Set 7 | letpadan
# Processing record 47 of Set 7 | cedar city
# Processing record 48 of Set 7 | esperance
# Processing record 49 of Set 7 | kirkwall
# Processing record 0 of Set 8 | shizilu
# Processing record 1 of Set 8 | jaipur hat
# City not found. Skipping...
# Processing record 2 of Set 8 | hofn
# Processing record 3 of Set 8 | jalu
# Processing record 4 of Set 8 | umtata
# Processing record 5 of Set 8 | sidrolandia
# Processing record 6 of Set 8 | mogadishu
# Processing record 7 of Set 8 | deputatskiy
# Processing record 8 of Set 8 | talaya
# Processing record 9 of Set 8 | tilichiki
# Processing record 10 of Set 8 | kandrian
# Processing record 11 of Set 8 | castro
# Processing record 12 of Set 8 | bambous virieux
# Processing record 13 of Set 8 | peresichna
# Processing record 14 of Set 8 | cap-aux-meules
# Processing record 15 of Set 8 | easton
# Processing record 16 of Set 8 | yuzhno-kurilsk
# Processing record 17 of Set 8 | cidreira
# Processing record 18 of Set 8 | kristiinankaupunki
# City not found. Skipping...
# Processing record 19 of Set 8 | arkhara
# Processing record 20 of Set 8 | umm lajj
# Processing record 21 of Set 8 | almaznyy
# Processing record 22 of Set 8 | burns lake
# Processing record 23 of Set 8 | okha
# Processing record 24 of Set 8 | sahrak
# City not found. Skipping...
# Processing record 25 of Set 8 | tumannyy
# City not found. Skipping...
# Processing record 26 of Set 8 | chumikan
# Processing record 27 of Set 8 | palu
# Processing record 28 of Set 8 | gara
# Processing record 29 of Set 8 | najran
# Processing record 30 of Set 8 | joao pinheiro
# Processing record 31 of Set 8 | daru
# Processing record 32 of Set 8 | derzhavinsk
# Processing record 33 of Set 8 | oktyabrskoye
# Processing record 34 of Set 8 | kilkis
# Processing record 35 of Set 8 | yongzhou
# Processing record 36 of Set 8 | luena
# Processing record 37 of Set 8 | bur gabo
# City not found. Skipping...
# Processing record 38 of Set 8 | yerbogachen
# Processing record 39 of Set 8 | aktash
# City not found. Skipping...
# Processing record 40 of Set 8 | klaksvik
# Processing record 41 of Set 8 | weligama
# Processing record 42 of Set 8 | timra
# Processing record 43 of Set 8 | buala
# Processing record 44 of Set 8 | longlac
# City not found. Skipping...
# Processing record 45 of Set 8 | shache
# Processing record 46 of Set 8 | winnemucca
# Processing record 47 of Set 8 | nemuro
# Processing record 48 of Set 8 | komsomolskiy
# Processing record 49 of Set 8 | salinopolis
# Processing record 0 of Set 9 | iaciara
# Processing record 1 of Set 9 | aswan
# Processing record 2 of Set 9 | karpathos
# Processing record 3 of Set 9 | the valley
# Processing record 4 of Set 9 | svay rieng
# Processing record 5 of Set 9 | egvekinot
# Processing record 6 of Set 9 | lata
# Processing record 7 of Set 9 | tazovskiy
# Processing record 8 of Set 9 | tessalit
# Processing record 9 of Set 9 | andra
# Processing record 10 of Set 9 | kendari
# Processing record 11 of Set 9 | garissa
# Processing record 12 of Set 9 | srednekolymsk
# Processing record 13 of Set 9 | leshukonskoye
# Processing record 14 of Set 9 | anloga
# Processing record 15 of Set 9 | kirensk
# Processing record 16 of Set 9 | gorodovikovsk
# Processing record 17 of Set 9 | akcakoca
# Processing record 18 of Set 9 | alexandria
# Processing record 19 of Set 9 | yeppoon
# Processing record 20 of Set 9 | great falls
# Processing record 21 of Set 9 | craig
# Processing record 22 of Set 9 | nishihara
# Processing record 23 of Set 9 | ribeira grande
# Processing record 24 of Set 9 | sabang
# Processing record 25 of Set 9 | safaga
# City not found. Skipping...
# Processing record 26 of Set 9 | fukue
# Processing record 27 of Set 9 | karpogory
# Processing record 28 of Set 9 | ourossogui
# Processing record 29 of Set 9 | belomorsk
# Processing record 30 of Set 9 | alotau
# City not found. Skipping...
# Processing record 31 of Set 9 | aporawan
# City not found. Skipping...
# Processing record 32 of Set 9 | cayenne
# Processing record 33 of Set 9 | dasoguz
# Processing record 34 of Set 9 | aklavik
# Processing record 35 of Set 9 | port pirie
# Processing record 36 of Set 9 | meleuz
# Processing record 37 of Set 9 | pierre
# Processing record 38 of Set 9 | qasigiannguit
# Processing record 39 of Set 9 | inirida
# Processing record 40 of Set 9 | lebu
# Processing record 41 of Set 9 | jackson
# Processing record 42 of Set 9 | tambopata
# City not found. Skipping...
# Processing record 43 of Set 9 | sambava
# Processing record 44 of Set 9 | mayo
# Processing record 45 of Set 9 | wicklow
# Processing record 46 of Set 9 | acapulco
# Processing record 47 of Set 9 | kaeo
# Processing record 48 of Set 9 | aykhal
# Processing record 49 of Set 9 | kazanka
# Processing record 0 of Set 10 | tuatapere
# Processing record 1 of Set 10 | pishin
# Processing record 2 of Set 10 | ponta do sol
# Processing record 3 of Set 10 | malibu
# Processing record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing record 5 of Set 10 | bereznik
# Processing record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing record 7 of Set 10 | qandala
# Processing record 8 of Set 10 | messina
# Processing record 9 of Set 10 | gistrup
# Processing record 10 of Set 10 | jawhar
# Processing record 11 of Set 10 | bereda
# Processing record 12 of Set 10 | beboto
# Processing record 13 of Set 10 | ryotsu
# Processing record 14 of Set 10 | bongandanga
# Processing record 15 of Set 10 | erenhot
# Processing record 16 of Set 10 | ayagoz
# Processing record 17 of Set 10 | kamyshin
# Processing record 18 of Set 10 | gampaha
# Processing record 19 of Set 10 | brae
# Processing record 20 of Set 10 | yumen
# Processing record 21 of Set 10 | kaspiyskiy
# Processing record 22 of Set 10 | russell
# Processing record 23 of Set 10 | guerrero negro
# Processing record 24 of Set 10 | volokolamsk
# Processing record 25 of Set 10 | primore
# City not found. Skipping...
# Processing record 26 of Set 10 | migori
# Processing record 27 of Set 10 | gazojak
# Processing record 28 of Set 10 | adrar
# Processing record 29 of Set 10 | kondinskoye
# Processing record 30 of Set 10 | guia de isora
# Processing record 31 of Set 10 | geraldton
# Processing record 32 of Set 10 | emerald
# Processing record 33 of Set 10 | ninghai
# Processing record 34 of Set 10 | kuopio
# Processing record 35 of Set 10 | sur
# Processing record 36 of Set 10 | chapais
# Processing record 37 of Set 10 | dharchula
# Processing record 38 of Set 10 | manta
# Processing record 39 of Set 10 | semnan
# Processing record 40 of Set 10 | qingyuan
# Processing record 41 of Set 10 | yei
# City not found. Skipping...
# Processing record 42 of Set 10 | normandin
# Processing record 43 of Set 10 | guaraniacu
# Processing record 44 of Set 10 | kamiiso
# Processing record 45 of Set 10 | harnai
# Processing record 46 of Set 10 | mahajanga
# Processing record 47 of Set 10 | abong mbang
# Processing record 48 of Set 10 | uk
# City not found. Skipping...
# Processing record 49 of Set 10 | tezu
# Processing record 0 of Set 11 | gurskoye
# City not found. Skipping...
# Processing record 1 of Set 11 | keshan
# City not found. Skipping...
# Processing record 2 of Set 11 | channagiri
# Processing record 3 of Set 11 | sorong
# Processing record 4 of Set 11 | kompaniyivka
# Processing record 5 of Set 11 | velur
# Processing record 6 of Set 11 | bambanglipuro
# Processing record 7 of Set 11 | broome
# Processing record 8 of Set 11 | ostashkov
# Processing record 9 of Set 11 | karamay
# City not found. Skipping...
# Processing record 10 of Set 11 | toucheng
# Processing record 11 of Set 11 | khash
# Processing record 12 of Set 11 | caorle
# Processing record 13 of Set 11 | marabba
# Processing record 14 of Set 11 | tarakan
# Processing record 15 of Set 11 | ruatoria
# City not found. Skipping...
# Processing record 16 of Set 11 | gulshat
# City not found. Skipping...
# Processing record 17 of Set 11 | waipawa
# Processing record 18 of Set 11 | bafq
# Processing record 19 of Set 11 | sug-aksy
# City not found. Skipping...
# Processing record 20 of Set 11 | igarka
# Processing record 21 of Set 11 | san jeronimo
# Processing record 22 of Set 11 | oum hadjer
# Processing record 23 of Set 11 | opuwo
# Processing record 24 of Set 11 | vila
# Processing record 25 of Set 11 | touros
# Processing record 26 of Set 11 | oranjemund
# Processing record 27 of Set 11 | waingapu
# Processing record 28 of Set 11 | vila franca do campo
# Processing record 29 of Set 11 | gari
# Processing record 30 of Set 11 | mahon
# Processing record 31 of Set 11 | vila velha
# Processing record 32 of Set 11 | toora-khem
# Processing record 33 of Set 11 | somerset
# Processing record 34 of Set 11 | francistown
# Processing record 35 of Set 11 | yellamanchili
# City not found. Skipping...
# Processing record 36 of Set 11 | bria
# Processing record 37 of Set 11 | pathein
# Processing record 38 of Set 11 | gat
# Processing record 39 of Set 11 | shestakovo
# Processing record 40 of Set 11 | mackay
# Processing record 41 of Set 11 | san jose
# Processing record 42 of Set 11 | dubbo
# Processing record 43 of Set 11 | mehran
# Processing record 44 of Set 11 | muzquiz
# City not found. Skipping...
# Processing record 45 of Set 11 | dingzhou
# Processing record 46 of Set 11 | trairi
# Processing record 47 of Set 11 | kamenka
# Processing record 48 of Set 11 | jerome
# Processing record 49 of Set 11 | half moon bay
# Processing record 0 of Set 12 | boende
# Processing record 1 of Set 12 | agra
# Processing record 2 of Set 12 | tadine
# Processing record 3 of Set 12 | lipin bor
# Processing record 4 of Set 12 | aberdeen
# Processing record 5 of Set 12 | mananjary
# Processing record 6 of Set 12 | san joaquin
# Processing record 7 of Set 12 | damara
# Processing record 8 of Set 12 | bahile
# Processing record 9 of Set 12 | novyy urengoy
# Processing record 10 of Set 12 | kisesa
# Processing record 11 of Set 12 | dali
# Processing record 12 of Set 12 | taburao
# City not found. Skipping...
# Processing record 13 of Set 12 | santiago del estero
# Processing record 14 of Set 12 | minna
# Processing record 15 of Set 12 | shar
# Processing record 16 of Set 12 | drochia
# Processing record 17 of Set 12 | te anau
# Processing record 18 of Set 12 | saint-joseph
# Processing record 19 of Set 12 | mrirt
# City not found. Skipping...
# Processing record 20 of Set 12 | saravan
# Processing record 21 of Set 12 | marsala
# Processing record 22 of Set 12 | lagos
# Processing record 23 of Set 12 | alaca
# Processing record 24 of Set 12 | caruray
# Processing record 25 of Set 12 | yulara
# Processing record 26 of Set 12 | malumfashi
# Processing record 27 of Set 12 | krosno odrzanskie
# Processing record 28 of Set 12 | adet
# Processing record 29 of Set 12 | padang
# Processing record 30 of Set 12 | pochutla
# Processing record 31 of Set 12 | dawei
# Processing record 32 of Set 12 | kudahuvadhoo
# Processing record 33 of Set 12 | artyk
# City not found. Skipping...
# Processing record 34 of Set 12 | wencheng
# Processing record 35 of Set 12 | pacific grove
# Processing record 36 of Set 12 | campbell river
# Processing record 37 of Set 12 | sumbawa
# City not found. Skipping...
# Processing record 38 of Set 12 | lensk
# Processing record 39 of Set 12 | praia da vitoria
# Processing record 40 of Set 12 | roros
# Processing record 41 of Set 12 | carlagan
# Processing record 42 of Set 12 | lodja
# Processing record 43 of Set 12 | burnie
# Processing record 44 of Set 12 | cananea
# Processing record 45 of Set 12 | kungurtug
# Processing record 46 of Set 12 | chuy
# Processing record 47 of Set 12 | muscat
# Processing record 48 of Set 12 | cockburn town
# Processing record 49 of Set 12 | dunedin
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -45.87, 'lon': 170.5},
#  'dt': 1552485585,
#  'id': 2191562,
#  'main': {'humidity': 65,
#           'pressure': 1018,
#           'temp': 55,
#           'temp_max': 55,
#           'temp_min': 55},
#  'name': 'Dunedin',
#  'rain': {'3h': 0.015},
#  'sys': {'country': 'NZ',
#          'id': 75281,
#          'message': 0.0038,
#          'sunrise': 1552415425,
#          'sunset': 1552460622,
#          'type': 3},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'gust': 8.05, 'speed': 5.01}}

# %%
# Use list comprehension to gather necessary data series
lat_data = [data.get("coord").get("lat") for data in search_data]
lng_data = [data.get("coord").get("lon") for data in search_data]
temp_max = [data.get("main").get("temp_max") for data in search_data]
humid_data = [data.get("main").get("humidity") for data in search_data]
cloud_data =[data.get("clouds").get("all") for data in search_data]
wind_data = [data.get("wind").get("speed") for data in search_data]
date_data = [data.get("dt")for data in search_data]

# %%
# Create data frame with aggregated data
weather_data = pd.DataFrame({"City":cityList,
                             "Cloudiness":cloud_data,
                             "Country":countryList,
                             "Date":date_data,
                             "Humidity":humid_data,
                             "Lat":lat_data,
                             "Lng":lng_data,
                             "Max Temp":temp_max,
                             "Wind Speed":wind_data})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = weather_data[["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]]
weather_data.count()
# Out:
# City          526
# Cloudiness    526
# Country       526
# Date          526
# Humidity      526
# Lat           526
# Lng           526
# Max Temp      526
# Wind Speed    526
# dtype: int64

# %%
weather_data.head(10)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       mataura           8      nz  1552485004        80 -46.19  168.86
# 1          faya          40      pf  1552482000        49  18.39   42.45
# 2       slantsy           0      td  1552485558        68  59.12   28.09
# 3     cape town          20      ru  1552485363        57 -33.93   18.42
# 4       sonipat          75      za  1552484707        46  29.00   77.02
# 5          gore          56      in  1552485559        33   8.15   35.53
# 6  port lincoln           0      et  1552485559       100 -34.72  135.86
# 7    nikolskoye          90      au  1552485335        68  59.70   30.79
# 8   new norfolk          20      ru  1552485439        71 -42.78  147.06
# 9      khatanga          32      au  1552485560        72  71.98  102.47
#
#    Max Temp  Wind Speed
# 0     50.00        1.99
# 1     73.40       25.28
# 2     29.18        6.51
# 3     78.01        9.17
# 4     75.99        5.82
# 5     81.02        3.20
# 6     57.71        6.06
# 7     30.00        6.71
# 8     50.00        1.12
# 9    -16.45        2.59

# %%
# Save csv file
output_data_file=weather_data.to_csv("../output_data/cities.csv", index=False)

# %%
# Convert Unix Time Stamp to regular date
tmpDate = datetime.datetime.fromtimestamp(int(weather_data["Date"][0])).strftime('%Y-%m-%d')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Max Temp"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Max Temperature (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.ylim(30, 100)

plt.savefig("../output_data/MaxTmp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Humidity"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Humidity (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../output_data/Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Cloudiness"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Cloudiness (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.ylim(20, 100)

plt.savefig("../output_data/Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Wind Speed (" + tmpDate + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.ylim(0, 30)

plt.savefig("../output_data/WindSpeed.png")

plt.show()
